# %%
from scipy import stats
import pandas as pd
import numpy as np

# %%
class robo:
  def __init__(self,dados):
    self.dados = dados
    self.dados = pd.read_csv(dados)
  def removendo_dados_nulos(self):
    #limpando dados nulos
    self.v_f = self.dados.isnull().sum() > 200
    self.v_f = v_f.loc[v_f == True]
    for self.c in self.v_f.index:
      df.drop(self.c,inplace=True,axis=1)
  def substituindo_media(self):
    # Pegando a media desse valores e colocando no lugar dos valores nulos
    media_median = df.isnull().sum() > 0
    media_median = media_median.loc[media_median == True]
    for j in media_median.index:
      media = df[j].mean()
      mediana = df[j].median()
      # Aplicando a media nos dados ausentes
      teste = df[j].fillna(media,inplace=True) #Talvez não estaja funcionando

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/latest/owid-covid-latest.csv")
df_acrupados = df.groupby("continent")[['total_cases','total_deaths']].mean()
df_acrupados
# Out:
#                 total_cases   total_deaths
# continent
# Africa         2.299166e+05    4625.017857
# Asia           6.648955e+06   36274.755556
# Europe         4.883179e+06   41488.800000
# North America  3.034582e+06   39093.292683
# Oceania        6.004355e+05    1383.142857
# South America  4.914549e+06  104311.846154

# %%
#limpando dados nulos
v_f = df.isnull().sum() > 200
v_f = v_f.loc[v_f == True]
for c in v_f.index:
  df.drop(c,inplace=True,axis=1)

# %%
df
# Out:
#      iso_code continent           location last_updated_date  total_cases  \
# 0         AFG      Asia        Afghanistan        2023-07-30     224057.0
# 1    OWID_AFR       NaN             Africa        2023-07-26   13105032.0
# 2         ALB    Europe            Albania        2023-07-26     334090.0
# 3         DZA    Africa            Algeria        2023-07-26     271852.0
# 4         ASM   Oceania     American Samoa        2023-07-26       8332.0
# ..        ...       ...                ...               ...          ...
# 245       WLF   Oceania  Wallis and Futuna        2023-07-26       3550.0
# 246  OWID_WRL       NaN              World        2023-08-01  768559963.0
# 247       YEM      Asia              Yemen        2023-07-26      11945.0
# 248       ZMB    Africa             Zambia        2023-07-26     349287.0
# 249       ZWE    Africa           Zimbabwe        2023-07-26     265666.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0          0.0              18.286        7933.0         0.0
# 1          0.0              10.286      258999.0         0.0
# 2          0.0               0.000        3604.0         0.0
# 3          0.0               0.000        6881.0         0.0
# 4          0.0               0.000          34.0         0.0
# ..         ...                 ...           ...         ...
# 245        0.0               0.000           8.0         0.0
# 246        0.0           41415.857     6952509.0         0.0
# 247        0.0               0.000        2159.0         0.0
# 248        0.0               0.000        4069.0         0.0
# 249        0.0               0.000        5711.0         0.0
#
#      new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 0                  0.143  ...              NaN                597.029
# 1                  0.000  ...              NaN                    NaN
# 2                  0.000  ...              1.1                304.195
# 3                  0.000  ...              0.5                278.364
# 4                  0.000  ...              NaN                283.750
# ..                   ...  ...              ...                    ...
# 245                0.000  ...              NaN                    NaN
# 246               53.714  ...             10.0                233.070
# 247                0.000  ...             18.8                495.003
# 248                0.000  ...             57.5                234.499
# 249                0.000  ...             21.4                307.846
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# 0                   9.59             NaN           NaN
# 1                    NaN             NaN           NaN
# 2                  10.08           7.100        51.200
# 3                   6.73           0.700        30.400
# 4                    NaN             NaN           NaN
# ..                   ...             ...           ...
# 245                  NaN             NaN           NaN
# 246                 8.51           6.434        34.635
# 247                 5.35           7.600        29.200
# 248                 3.94           3.100        24.700
# 249                 1.82           1.600        30.700
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                    37.746                       0.500            64.83
# 1                       NaN                         NaN              NaN
# 2                       NaN                       2.890            78.57
# 3                    83.741                       1.900            76.88
# 4                       NaN                         NaN            73.74
# ..                      ...                         ...              ...
# 245                     NaN                         NaN            79.94
# 246                  60.130                       2.705            72.58
# 247                  49.542                       0.700            66.12
# 248                  13.938                       2.000            63.89
# 249                  36.791                       1.700            61.49
#
#      human_development_index    population
# 0                      0.511  4.112877e+07
# 1                        NaN  1.426737e+09
# 2                      0.795  2.842318e+06
# 3                      0.748  4.490323e+07
# 4                        NaN  4.429500e+04
# ..                       ...           ...
# 245                      NaN  1.159600e+04
# 246                    0.737  7.975105e+09
# 247                    0.470  3.369661e+07
# 248                    0.584  2.001767e+07
# 249                    0.571  1.632054e+07
#
# [250 rows x 31 columns]

# %%
df['continent'].fillna('País não encontrado',inplace=True)
df.isnull().sum()
# Out:
# iso_code                             0
# continent                            0
# location                             0
# last_updated_date                    0
# total_cases                          6
# new_cases                            4
# new_cases_smoothed                   4
# total_deaths                        12
# new_deaths                           4
# new_deaths_smoothed                  4
# total_cases_per_million              6
# new_cases_per_million                4
# new_cases_smoothed_per_million       4
# total_deaths_per_million            12
# new_deaths_per_million               4
# new_deaths_smoothed_per_million      4
# population_density                  36
# median_age                          52
# aged_65_older                       58
# aged_70_older                       54
# gdp_per_capita                      55
# extreme_poverty                    124
# cardiovasc_death_rate               55
# diabetes_prevalence                 44
# female_smokers                     103
# male_smokers                       105
# handwashing_facilities             154
# hospital_beds_per_thousand          77
# life_expectancy                     19
# human_development_index             60
# population                           0
# dtype: int64

# %%
# Pegando a media desse valores e colocando no lugar dos valores nulos
media_median = df.isnull().sum() > 0
media_median = media_median.loc[media_median == True]
for j in media_median.index:
  media = df[j].mean()
  mediana = df[j].median()
  # Aplicando a media nos dados ausentes
  teste = df[j].fillna(media,inplace=True) #Talvez não estaja funcionando

# %%
outlines = df.drop(['iso_code','continent','location'],axis=1)
outlines
# Out:
#     last_updated_date  total_cases  new_cases  new_cases_smoothed  \
# 0          2023-08-02     224201.0        0.0              10.429
# 1          2023-08-02   13105246.0        0.0               6.857
# 2          2023-08-02     334090.0        0.0               0.000
# 3          2023-08-02     271852.0        0.0               0.000
# 4          2023-08-02       8332.0        0.0               0.000
# ..                ...          ...        ...                 ...
# 245        2023-08-02       3550.0        0.0               0.000
# 246        2023-08-03  768982331.0        0.0           50420.571
# 247        2023-08-02      11945.0        0.0               0.000
# 248        2023-08-02     349287.0        0.0               0.000
# 249        2023-08-02     265693.0        0.0               0.000
#
#      total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# 0          7940.0         0.0                0.857                 5451.196
# 1        259001.0         0.0                0.143                 9185.470
# 2          3604.0         0.0                0.000               117541.387
# 3          6881.0         0.0                0.000                 6054.175
# 4            34.0         0.0                0.000               188102.495
# ..            ...         ...                  ...                      ...
# 245           8.0         0.0                0.000               306140.048
# 246     6953730.0         0.0               96.286                96422.847
# 247        2159.0         0.0                0.000                  354.487
# 248        4069.0         0.0                0.000                17448.934
# 249        5712.0         0.0                0.143                16279.671
#
#      new_cases_per_million  new_cases_smoothed_per_million  ...  \
# 0                      0.0                           0.254  ...
# 1                      0.0                           0.005  ...
# 2                      0.0                           0.000  ...
# 3                      0.0                           0.000  ...
# 4                      0.0                           0.000  ...
# ..                     ...                             ...  ...
# 245                    0.0                           0.000  ...
# 246                    0.0                           6.322  ...
# 247                    0.0                           0.000  ...
# 248                    0.0                           0.000  ...
# 249                    0.0                           0.000  ...
#
#      extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0          13.848413             597.029000             9.590000
# 1          13.848413             265.089723             8.561068
# 2           1.100000             304.195000            10.080000
# 3           0.500000             278.364000             6.730000
# 4          13.848413             283.750000             8.561068
# ..               ...                    ...                  ...
# 245        13.848413             265.089723             8.561068
# 246        10.000000             233.070000             8.510000
# 247        18.800000             495.003000             5.350000
# 248        57.500000             234.499000             3.940000
# 249        21.400000             307.846000             1.820000
#
#      female_smokers  male_smokers  handwashing_facilities  \
# 0         10.790027     32.909897               37.746000
# 1         10.790027     32.909897               50.788844
# 2          7.100000     51.200000               50.788844
# 3          0.700000     30.400000               83.741000
# 4         10.790027     32.909897               50.788844
# ..              ...           ...                     ...
# 245       10.790027     32.909897               50.788844
# 246        6.434000     34.635000               60.130000
# 247        7.600000     29.200000               49.542000
# 248        3.100000     24.700000               13.938000
# 249        1.600000     30.700000               36.791000
#
#      hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                      0.500000        64.830000                   0.5110
# 1                      3.097012        73.660866                   0.7225
# 2                      2.890000        78.570000                   0.7950
# 3                      1.900000        76.880000                   0.7480
# 4                      3.097012        73.740000                   0.7225
# ..                          ...              ...                      ...
# 245                    3.097012        79.940000                   0.7225
# 246                    2.705000        72.580000                   0.7370
# 247                    0.700000        66.120000                   0.4700
# 248                    2.000000        63.890000                   0.5840
# 249                    1.700000        61.490000                   0.5710
#
#        population
# 0    4.112877e+07
# 1    1.426737e+09
# 2    2.842318e+06
# 3    4.490323e+07
# 4    4.429500e+04
# ..            ...
# 245  1.159600e+04
# 246  7.975105e+09
# 247  3.369661e+07
# 248  2.001767e+07
# 249  1.632054e+07
#
# [250 rows x 28 columns]

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  2.500000e+02     250.000000          250.000000  2.500000e+02
# mean   1.334725e+07    1166.268293          677.139967  1.220521e+05
# std    6.443973e+07   16129.200375         4796.145035  5.589534e+05
# min    4.000000e+00       0.000000            0.000000  1.000000e+00
# 25%    3.040700e+04       0.000000            0.000000  2.925000e+02
# 50%    2.661705e+05       0.000000            0.000000  3.175500e+03
# 75%    2.163449e+06       0.000000            0.107250  2.656150e+04
# max    7.685600e+08  254841.000000        41415.857000  6.952509e+06
#
#        new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  250.000000           250.000000               250.000000
# mean     1.284553             0.887350            201697.077881
# std     11.365077             4.889603            194767.373965
# min      0.000000             0.000000               354.487000
# 25%      0.000000             0.000000             28538.009500
# 50%      0.000000             0.000000            147780.885500
# 75%      0.000000             0.000000            328575.737750
# max    168.000000            53.714000            737554.506000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count             250.000000                      250.000000
# mean               29.342126                        4.802557
# std               317.610547                       45.446568
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.000000
# 50%                 0.000000                        0.000000
# 75%                 0.000000                        0.005250
# max              4918.210000                      702.601000
#
#        total_deaths_per_million  ...  extreme_poverty  cardiovasc_death_rate  \
# count                250.000000  ...       250.000000             250.000000
# mean                1294.444782  ...        13.848413             265.089723
# std                 1262.839239  ...        14.292323             106.809309
# min                    1.164000  ...         0.100000              79.370000
# 25%                  195.479000  ...         2.500000             200.050750
# 50%                 1014.183500  ...        13.848413             265.089723
# 75%                 1991.910500  ...        13.848413             302.366250
# max                 6498.199000  ...        77.600000             724.417000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count           250.000000      250.000000    250.000000
# mean              8.561068       10.790027     32.909897
# std               4.494200        8.282375     10.358925
# min               0.990000        0.100000      7.700000
# 25%               5.772500        5.025000     29.400000
# 50%               8.420000       10.790027     32.909897
# 75%              10.080000       10.790027     34.800000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count              250.000000                  250.000000       250.000000
# mean                50.788844                    3.097012        73.660866
# std                 19.842811                    2.124161         7.117572
# min                  1.188000                    0.100000        53.280000
# 25%                 50.788844                    1.702500        70.030000
# 50%                 50.788844                    3.097012        74.205000
# 75%                 50.788844                    3.099253        78.910000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index    population
# count               250.000000  2.500000e+02
# mean                  0.722500  1.294521e+08
# std                   0.130159  6.645074e+08
# min                   0.394000  4.700000e+01
# 25%                   0.663500  4.677010e+05
# 50%                   0.722500  5.926344e+06
# 75%                   0.809000  2.928421e+07
# max                   0.957000  7.975105e+09
#
# [8 rows x 27 columns]

# %%
# Indentificando outliers
z_score = np.abs(stats.zscore(df['medv']))
print(z_score)

# %% [markdown]
# #TESTE PARA OUTLIERS

# %%
# Teste
for h in outlines:
  minimo = outlines.min()
  maximo = outlines.max()
print(minimo)
print('-'*90)
print(maximo)
desvio_padrao = np.std(df).sum()
media = np.mean(df).sum()
print(desvio_padrao)
print('-'*90)
print(media)
print('-'*90)
variacao = desvio_padrao/media
variacao
