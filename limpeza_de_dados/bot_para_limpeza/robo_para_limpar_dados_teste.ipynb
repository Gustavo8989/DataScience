# %%
import pandas as pd
import numpy as np

# %%
class robo:
  def __init__(self,dados):
    self.dados = dados
    self.dados = pd.read_csv(dados)
  def removendo_dados_nulos(self):
    #limpando dados nulos
    self.v_f = self.dados.isnull().sum() > 200
    self.v_f = v_f.loc[v_f == True]
    for self.c in self.v_f.index:
      df.drop(self.c,inplace=True,axis=1)
  def substituindo_media(self):
    # Pegando a media desse valores e colocando no lugar dos valores nulos
    pass

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/latest/owid-covid-latest.csv")
df_acrupados = df.groupby("continent")[['total_cases','total_deaths']].mean()
df_acrupados
# Out:
#                 total_cases   total_deaths
# continent
# Africa         2.299128e+05    4624.982143
# Asia           6.641206e+06   36268.288889
# Europe         4.882821e+06   41482.580000
# North America  3.034404e+06   39090.658537
# Oceania        5.990869e+05    1373.380952
# South America  4.913438e+06  104288.461538

# %%
#limpando dados nulos
v_f = df.isnull().sum() > 200
v_f = v_f.loc[v_f == True]
for c in v_f.index:
  df.drop(c,inplace=True,axis=1)

# %%
df
# Out:
#      iso_code continent           location last_updated_date  total_cases  \
# 0         AFG      Asia        Afghanistan        2023-07-26     224057.0
# 1    OWID_AFR       NaN             Africa        2023-07-26   13105032.0
# 2         ALB    Europe            Albania        2023-07-26     334090.0
# 3         DZA    Africa            Algeria        2023-07-26     271852.0
# 4         ASM   Oceania     American Samoa        2023-07-26       8332.0
# ..        ...       ...                ...               ...          ...
# 244       WLF   Oceania  Wallis and Futuna        2023-07-26       3550.0
# 245  OWID_WRL       NaN              World        2023-07-30  768559963.0
# 246       YEM      Asia              Yemen        2023-07-26      11945.0
# 247       ZMB    Africa             Zambia        2023-07-26     349287.0
# 248       ZWE    Africa           Zimbabwe        2023-07-26     265666.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0          0.0              18.286        7933.0         0.0
# 1          0.0              10.286      258999.0         0.0
# 2          0.0               0.000        3604.0         0.0
# 3          0.0               0.000        6881.0         0.0
# 4          0.0               0.000          34.0         0.0
# ..         ...                 ...           ...         ...
# 244        0.0               0.000           8.0         0.0
# 245        0.0           41415.857     6952509.0         0.0
# 246        0.0               0.000        2159.0         0.0
# 247        0.0               0.000        4069.0         0.0
# 248        0.0               0.000        5711.0         0.0
#
#      new_deaths_smoothed  ...  extreme_poverty  cardiovasc_death_rate  \
# 0                  0.143  ...              NaN                597.029
# 1                  0.000  ...              NaN                    NaN
# 2                  0.000  ...              1.1                304.195
# 3                  0.000  ...              0.5                278.364
# 4                  0.000  ...              NaN                283.750
# ..                   ...  ...              ...                    ...
# 244                0.000  ...              NaN                    NaN
# 245               53.714  ...             10.0                233.070
# 246                0.000  ...             18.8                495.003
# 247                0.000  ...             57.5                234.499
# 248                0.000  ...             21.4                307.846
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# 0                   9.59             NaN           NaN
# 1                    NaN             NaN           NaN
# 2                  10.08           7.100        51.200
# 3                   6.73           0.700        30.400
# 4                    NaN             NaN           NaN
# ..                   ...             ...           ...
# 244                  NaN             NaN           NaN
# 245                 8.51           6.434        34.635
# 246                 5.35           7.600        29.200
# 247                 3.94           3.100        24.700
# 248                 1.82           1.600        30.700
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                    37.746                       0.500            64.83
# 1                       NaN                         NaN              NaN
# 2                       NaN                       2.890            78.57
# 3                    83.741                       1.900            76.88
# 4                       NaN                         NaN            73.74
# ..                      ...                         ...              ...
# 244                     NaN                         NaN            79.94
# 245                  60.130                       2.705            72.58
# 246                  49.542                       0.700            66.12
# 247                  13.938                       2.000            63.89
# 248                  36.791                       1.700            61.49
#
#      human_development_index    population
# 0                      0.511  4.112877e+07
# 1                        NaN  1.426737e+09
# 2                      0.795  2.842318e+06
# 3                      0.748  4.490323e+07
# 4                        NaN  4.429500e+04
# ..                       ...           ...
# 244                      NaN  1.159600e+04
# 245                    0.737  7.975105e+09
# 246                    0.470  3.369661e+07
# 247                    0.584  2.001767e+07
# 248                    0.571  1.632054e+07
#
# [249 rows x 31 columns]

# %%
df['continent'].fillna('País não encontrado',inplace=True)
df.isnull().sum()
# Out:
# iso_code                             0
# continent                            0
# location                             0
# last_updated_date                    0
# total_cases                          5
# new_cases                            3
# new_cases_smoothed                   3
# total_deaths                        11
# new_deaths                           3
# new_deaths_smoothed                  3
# total_cases_per_million              5
# new_cases_per_million                3
# new_cases_smoothed_per_million       3
# total_deaths_per_million            11
# new_deaths_per_million               3
# new_deaths_smoothed_per_million      3
# population_density                  36
# median_age                          52
# aged_65_older                       58
# aged_70_older                       54
# gdp_per_capita                      55
# extreme_poverty                    123
# cardiovasc_death_rate               54
# diabetes_prevalence                 44
# female_smokers                     102
# male_smokers                       104
# handwashing_facilities             153
# hospital_beds_per_thousand          76
# life_expectancy                     19
# human_development_index             60
# population                           0
# dtype: int64

# %%
# Pegando a media desse valores e colocando no lugar dos valores nulos
