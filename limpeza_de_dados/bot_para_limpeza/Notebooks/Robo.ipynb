# %%
from pathlib import path
import pandas as pd
import numpy as np
import os
import re

# %%
class limpeza_de_dados:
  def __init__(self,dados,qt_valores_nulos):
    self.dados = dados
    self.qt_valores_nulos = qt_valores_nulos
  def drop_null(self):
    pass
  def outliers(self):
    pass
