# %%
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/supermarket-sales/supermarket_sales - Sheet1.csv')
df.head()

# %%
df.columns

# %%
df.columns = ['Id da fatura','Filial','Cidade','Tipo de cliente','Genêro','Linha de producao',
             'Preco unitario','Quantidade','Taxa 5%','Total','Data','Horario','Pagamento','CPV',
             'Porcentagem da margem bruta','Renda bruta','Classificacao']

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
# Ver a correlação do dados 
colunas_numericas = ['int','float']
df_numericas = df.select_dtypes(include=colunas_numericas)
df_numericas

# %%
df_numericas.corr()

# %%
sns.histplot(
data = df,
    x = 'Total',
    kde = True,
);

# %%
sns.histplot(
    data=df,
    
)
